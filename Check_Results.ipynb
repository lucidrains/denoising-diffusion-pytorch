# %%
import torch 
import pickle

# %%
with open('sample.pkl', 'rb') as f:
    sample = pickle.load(f)

# %%
sample
# Out:
# tensor([[[0.0993, 0.3660, 0.3747,  ..., 0.4027, 0.4433, 0.5126]],
#
#         [[0.5298, 0.2857, 0.3880,  ..., 0.4598, 0.4766, 0.4789]],
#
#         [[0.4947, 0.3297, 0.4094,  ..., 0.4976, 0.5184, 0.7605]],
#
#         ...,
#
#         [[0.0520, 0.2806, 0.3726,  ..., 0.5756, 0.5807, 0.7174]],
#
#         [[0.2322, 0.3145, 0.4182,  ..., 0.3351, 0.3414, 0.3780]],
#
#         [[0.1767, 0.3808, 0.4763,  ..., 0.4891, 0.4889, 0.5699]]])

# %%
sample.shape
# Out:
# torch.Size([16, 1, 1000])

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.7.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 31.2 MB/s eta 0:00:00m eta 0:00:010:0101
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.1.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (300 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.4/300.4 kB 39.3 MB/s eta 0:00:00
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.40.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 46.0 MB/s eta 0:00:0031m59.7 MB/s eta 0:00:01
# Collecting kiwisolver>=1.0.1 (from matplotlib)
#   Downloading kiwisolver-1.4.4-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 42.1 MB/s eta 0:00:00m eta 0:00:01
# Requirement already satisfied: numpy>=1.20 in /mlainas/teang1995/anaconda3/envs/PPG/lib/python3.9/site-packages (from matplotlib) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /mlainas/teang1995/anaconda3/envs/PPG/lib/python3.9/site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /mlainas/teang1995/anaconda3/envs/PPG/lib/python3.9/site-packages (from matplotlib) (10.0.0)
# Collecting pyparsing<3.1,>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.0.9-py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.3/98.3 kB 35.4 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7 in /mlainas/teang1995/anaconda3/envs/PPG/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Collecting importlib-resources>=3.2.0 (from matplotlib)
#   Downloading importlib_resources-6.0.0-py3-none-any.whl (31 kB)
# Requirement already satisfied: zipp>=3.1.0 in /mlainas/teang1995/anaconda3/envs/PPG/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.16.0)
# Requirement already satisfied: six>=1.5 in /mlainas/teang1995/anaconda3/envs/PPG/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: pyparsing, kiwisolver, importlib-resources, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.1.0 cycler-0.11.0 fonttools-4.40.0 importlib-resources-6.0.0 kiwisolver-1.4.4 matplotlib-3.7.2 pyparsing-3.0.9

# %%
from matplotlib import pyplot as plt
sample_ = sample[0]
sample_ = sample_.squeeze()
sample_ = sample_.detach().numpy()
plt.plot(sample_)

# %%
import torch 
import pickle

# %%
with open('sample2.pkl', 'rb') as f:
    sample = pickle.load(f)

# %%
sample
# Out:
# tensor([[[0.5869, 0.5839, 0.5769,  ..., 0.3805, 0.3714, 0.3645]],
#
#         [[0.7262, 0.7298, 0.7235,  ..., 0.4654, 0.4604, 0.4574]],
#
#         [[0.3642, 0.3715, 0.3871,  ..., 0.4505, 0.4569, 0.4636]],
#
#         ...,
#
#         [[0.4208, 0.4143, 0.4077,  ..., 0.2985, 0.3039, 0.3140]],
#
#         [[0.3802, 0.3766, 0.3697,  ..., 0.4108, 0.4043, 0.3949]],
#
#         [[0.3717, 0.3673, 0.3624,  ..., 0.3511, 0.3428, 0.3372]]])

# %%
sample.shape
# Out:
# torch.Size([16, 1, 1000])

# %%
from matplotlib import pyplot as plt
sample_ = sample[5]
sample_ = sample_.squeeze()
sample_ = sample_.detach().numpy()
plt.plot(sample_)
